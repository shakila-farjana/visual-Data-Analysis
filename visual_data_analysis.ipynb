# %%
import pandas as pd
df = pd.read_csv("penguins_simple.csv", sep=';')

# %%
df.head(3)
# Out:
#   Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  Adelie                39.1               18.7                181.0
# 1  Adelie                39.5               17.4                186.0
# 2  Adelie                40.3               18.0                195.0
#
#    Body Mass (g)     Sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE

# %%
df['Body Mass (kg)'] = df['Body Mass (g)']*(0.001)

# %%
df["Body Mass (g)"] / 100
# Out:
# 0      37.50
# 1      38.00
# 2      32.50
# 3      34.50
# 4      36.50
#        ...
# 328    49.25
# 329    48.50
# 330    57.50
# 331    52.00
# 332    54.00
# Name: Body Mass (g), Length: 333, dtype: float64

# %% [markdown]
# ### calculate log of culmen length

# %%
import numpy as np
#df['Log culmen Length'] = np.log(df['Culmen Length (mm)'])
df['Culmen Lenght Log'] = np.log(df['Culmen Length (mm)'])
df.head(3)
# Out:
#   Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  Adelie                39.1               18.7                181.0
# 1  Adelie                39.5               17.4                186.0
# 2  Adelie                40.3               18.0                195.0
#
#    Body Mass (g)     Sex  Body Mass (kg)  Culmen Lenght Log
# 0         3750.0    MALE            3.75           3.666122
# 1         3800.0  FEMALE            3.80           3.676301
# 2         3250.0  FEMALE            3.25           3.696351

# %% [markdown]
# ### convert gender to Boolean

# %%
def convert(sex):
    if (sex == 'MALE'):
        return True
    else:
        return False
df['Sex (bool)'] = df ['Sex'].apply(convert)
df.head(3)
# Out:
#   Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  Adelie                39.1               18.7                181.0
# 1  Adelie                39.5               17.4                186.0
# 2  Adelie                40.3               18.0                195.0
#
#    Body Mass (g)     Sex  Body Mass (kg)  Culmen Lenght Log  Sex (bool)
# 0         3750.0    MALE            3.75           3.666122        True
# 1         3800.0  FEMALE            3.80           3.676301       False
# 2         3250.0  FEMALE            3.25           3.696351       False

# %%
pd.get_dummies(df['Sex']) #..you need this
# Out:
#      FEMALE  MALE
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 328       1     0
# 329       1     0
# 330       0     1
# 331       1     0
# 332       0     1
#
# [333 rows x 2 columns]

# %%
df['Sex']
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 328    FEMALE
# 329    FEMALE
# 330      MALE
# 331    FEMALE
# 332      MALE
# Name: Sex, Length: 333, dtype: object

# %%
#gender = {'MALE': False,'FEMALE': True}
#df['Sex'] = [gender[item] for item in df['Sex']]
#df.head(3)..:its a another way:

# %%
df.head(5)
# Out:
#   Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  Adelie                39.1               18.7                181.0
# 1  Adelie                39.5               17.4                186.0
# 2  Adelie                40.3               18.0                195.0
# 3  Adelie                36.7               19.3                193.0
# 4  Adelie                39.3               20.6                190.0
#
#    Body Mass (g)     Sex  Body Mass (kg)  Culmen Lenght Log  Sex (bool)
# 0         3750.0    MALE            3.75           3.666122        True
# 1         3800.0  FEMALE            3.80           3.676301       False
# 2         3250.0  FEMALE            3.25           3.696351       False
# 3         3450.0  FEMALE            3.45           3.602777       False
# 4         3650.0    MALE            3.65           3.671225        True

# %% [markdown]
# ### combine species and gender into one column

# %%
df['Combine'] = df['Species'] + '' + df['Sex'].astype(str)
#df['combine'] = df['Species'] + ' / ' + df['Sex'] # both column should be str :

# %%
df.head()
# Out:
#   Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  Adelie                39.1               18.7                181.0
# 1  Adelie                39.5               17.4                186.0
# 2  Adelie                40.3               18.0                195.0
# 3  Adelie                36.7               19.3                193.0
# 4  Adelie                39.3               20.6                190.0
#
#    Body Mass (g)    Sex  Body Mass (kg)  Log culmen Length  Culmen Lenght Log  \
# 0         3750.0  False            3.75           3.666122           3.666122
# 1         3800.0   True            3.80           3.676301           3.676301
# 2         3250.0   True            3.25           3.696351           3.696351
# 3         3450.0   True            3.45           3.602777           3.602777
# 4         3650.0  False            3.65           3.671225           3.671225
#
#    Sex (bool)      Combine
# 0        True  AdelieFalse
# ...

# %%
pd.get_dummies(df['Sex'])
# Out:
#      False  True
# 0        1      0
# 1        0      1
# 2        0      1
# 3        0      1
# 4        1      0
# ..     ...    ...
# 328      0      1
# 329      0      1
# 330      1      0
# 331      0      1
# 332      1      0
#
# [333 rows x 2 columns]
